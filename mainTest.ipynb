# %%
import cv2
import os
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras.utils import normalize
import matplotlib.pyplot as plt
from scipy import ndimage as nd
from scipy.ndimage import laplace, sobel, median_filter
from scipy import misc
from scipy.ndimage import laplace
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
import tensorflow_hub as hub

# %%
dataset = []
label = []

img_dir = './dataset/'

# %%
no_tumor_img = os.listdir(img_dir + 'no/')
for i, img_name in enumerate(no_tumor_img):
    if(img_name.split('.')[1] == 'jpg'):
        img=cv2.imread(img_dir+'no/'+img_name)
        img = Image.fromarray(img,'RGB')
        img=img.resize((128,128))
        img = nd.gaussian_filter(img,sigma = 1)
        img=laplace(img)
#         img = median_filter(img, size=3)  # Apply Median filter
#         img = sobel(img)  # Apply Sobel filter for edge detection

        dataset.append(img)
        label.append(0)

# %%
yes_tumor_img = os.listdir(img_dir + 'yes/')
for i, img_name in enumerate(yes_tumor_img):
    if(img_name.split('.')[1] == 'jpg'):
        img=cv2.imread(img_dir+'yes/'+img_name)
        img = Image.fromarray(img,'RGB')
        img=img.resize((128,128))
        img = nd.gaussian_filter(img,sigma = 1)
        img=laplace(img)
#         img = median_filter(img, size=3)  # Apply Median filter
#         img = sobel(img)  # Apply Sobel filter for edge detection

        dataset.append(img)
        label.append(1)

# %%
rr = int(input("GIVE THE IMAGE WHICH YOU WANT CHECK: "))
# Out:
# GIVE THE IMAGE WHICH YOU WANT CHECK: 2134

# %%
plt.imshow(dataset[rr])
